# %%
# SPARQL query preparation
from SPARQLWrapper import SPARQLWrapper, JSON
endpoint = SPARQLWrapper("http://114.212.81.217:8890/sparql/")
wd_prefix="http://www.wikidata.org/entity/"
node_prefix="nodeID://"

# %%
import pyodbc
def initialize_odbc_connection():
    global odbc_conn
    odbc_conn = pyodbc.connect(
        'DRIVER=/usr/local/lib/virtodbc.so;Host=114.212.81.217:1111;UID=dba;PWD=dba'
    )
    odbc_conn.setdecoding(pyodbc.SQL_CHAR, encoding='utf8')
    odbc_conn.setdecoding(pyodbc.SQL_WCHAR, encoding='utf8')
    odbc_conn.setencoding(encoding='utf8')
    print('Wikidata Virtuoso ODBC connected')

def query_with_odbc(query):
    try:
        with odbc_conn.cursor() as cursor:
            cursor.execute(query)
            rows = cursor.fetchall()
    except Exception as err:
        print(err)
        print(f"Query Execution Failed:{query}")
        initialize_odbc_connection()
        return []    
    return rows

initialize_odbc_connection()
# Out:
# Wikidata Virtuoso ODBC connected

# %%
def convert_time2value(raw_time_str):
    if raw_time_str=="null" or raw_time_str=="None":
        return "null"
    bc=""
    res=raw_time_str
    if res.startswith("-"):
        bc="-"
        res=res[1:]
    if res.find(':')!=-1:
        res=res[:(res.find(':')-2)].strip().strip('T').strip('Z')
    date_split_list=res.split('-')
    while len(date_split_list)<3:
        date_split_list.append("01")

    if int(date_split_list[0])==0:
        bc=""
    if int(date_split_list[1])<1 or int(date_split_list[1])>12:
        date_split_list[1]="01"
    if int(date_split_list[2])<1 or int(date_split_list[2])>31:
        date_split_list[2]="01"


    return bc+date_split_list[0]+date_split_list[1]+date_split_list[2]

def get_all_item_with_relations_list(r_dict,r_type="temporal fact",result_path=""):
    relation_stat=[]
    for relation in r_dict.keys():
        # variables for statistics for each relation
        this_r_stat={}
        this_r_stat["r"]=relation
        cnt=0
        st_cnt=0
        en_cnt=0
        point_cnt=0
        st_en_pair_cnt=0
        dup_cnt=0
        unk_cnt=0

        # differrent query for different relation types
        if r_type=="temporal fact":
            query = '''
                SPARQL
                PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                SELECT DISTINCT ?s ?e1 ?e2 ?st ?en ?time
                WHERE
                {{
                    # ?e1 p:{} ?s.
                    # ?s ps:{} ?e2.
                    # ?s a <http://wikiba.se/ontology#Statement>.
                    # ?e1 a <http://wikiba.se/ontology#Item>.

                    {{
                        # ?s pq:P580 ?st.
                        OPTIONAL {{?s pq:P582 ?en.}}
                        OPTIONAL {{?s pq:P585 ?time.}}
                    }}
                    UNION
                    {{
                        # ?s pq:P582 ?en.
                        OPTIONAL {{?s pq:P580 ?st.}}
                        OPTIONAL {{?s pq:P585 ?time.}}
                    }}
                    UNION
                    {{
                        # ?s pq:P585 ?time.
                        OPTIONAL {{?s pq:P580 ?st.}}
                        OPTIONAL{{?s pq:P582 ?en.}}
                    }}
                }}
                '''.format(relation,relation)
        elif r_type=="time property":
            query = '''
                SPARQL
                PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                SELECT DISTINCT ?s ?e1 ?e2 ?st ?en ?time
                WHERE
                {{
                    # ?e1 p:{} ?s.
                    # ?s ps:{} ?e2.

                    OPTIONAL {{?s pq:P580 ?st.}}
                    OPTIONAL {{?s pq:P582 ?en.}}
                    OPTIONAL {{?s pq:P585 ?time.}}
                }}
                '''.format(relation,relation)
        # print(query)

        results=query_with_odbc(query)
        print("%s Query complete! count:%d" % (relation,len(results)))
        results.sort(key=lambda ele: ele[0])

        # process query results
        query_res=[]
        for i in range(len(results)):
            # unknown value check
            each_result=results[i]
            unkv_exists=False
            for ele in each_result:
                if (str(ele)).startswith(node_prefix):
                    unkv_exists=True
                    break
            if unkv_exists:
                unk_cnt+=1
                # if unk_cnt<=5:
                #     print("UNK Warning!%s" %(str(each_result)))                
                continue

            # dup check
            equal2last=False
            equal2next=False
            if i>0:
                if results[i][0]==results[i-1][0]:
                    # print("duplication detected:%s" %results[i][0])
                    equal2last=True
            if i<(len(results)-1):
                if results[i][0]==results[i+1][0]:
                    # print("duplication detected:%s" %results[i][0])
                    equal2next=True
            if (equal2last or equal2next) and (r_dict[relation]=="period") and (r_type=="temporal fact"):
                dup_cnt+=1
                # print("DUP Alert!%s" %(str(each_result)))
                continue

            temporal_fact={}

            if each_result[1].startswith(wd_prefix):
                temporal_fact["s"]=each_result[1][31:]
            else:
                print("S NOT ENTITY Alert!%s" %(str(each_result)))
                continue
            
            temporal_fact["p"]=relation

            if r_type=="time property":
                temporal_fact["o"] = str(each_result[2])
                temporal_fact["t1"] = convert_time2value(str(each_result[2]))
                temporal_fact["t2"] = convert_time2value(str(each_result[2]))
            elif r_type=="temporal fact":
                if(each_result[3]==None and each_result[4]==None and each_result[5]==None):
                    print("ALL TIME NULL Alert!%s" %(str(each_result)))
                    continue
                if each_result[2].startswith(wd_prefix):
                    temporal_fact["o"]=each_result[2][31:]
                else:
                    temporal_fact["o"]=each_result[2]
                if (r_dict[relation]=="point" and each_result[5]==None) or (r_dict[relation]=="period" and (each_result[3]!=None or each_result[4]!=None)):
                    temporal_fact["t1"] = convert_time2value(str(each_result[3]))
                    temporal_fact["t2"] = convert_time2value(str(each_result[4]))
                elif (r_dict[relation]=="point" and each_result[5]!=None) or (r_dict[relation]=="period" and each_result[3]==None and each_result[4]==None):
                    temporal_fact["t1"] = convert_time2value(str(each_result[5]))
                    temporal_fact["t2"] = convert_time2value(str(each_result[5]))

            if each_result[3]!=None:
                st_cnt+=1
            if each_result[4]!=None:
                en_cnt+=1
            if (each_result[3]!=None)and(each_result[4]!=None):
                st_en_pair_cnt+=1
            if each_result[5]!=None:
                point_cnt+=1
            cnt+=1
            query_res.append(temporal_fact)

        this_r_stat["cnt"]=cnt
        this_r_stat["st_cnt"]=st_cnt
        this_r_stat["en_cnt"]=en_cnt
        this_r_stat["st_en_pair_ent"]=st_en_pair_cnt
        this_r_stat["point_cnt"]=point_cnt
        this_r_stat["dup_cnt"]=dup_cnt
        this_r_stat["unk_cnt"]=unk_cnt
        relation_stat.append(this_r_stat)
        f=open("%s/%sres.tsv" %(result_path,relation),"w")
        for tf in query_res:
            f.write("%s\t%s\t%s\t%s\t%s\n" %(tf["s"],tf["p"],tf["o"],tf["t1"],tf["t2"]))
        f.close()
    return relation_stat

# %%
# get_all_item_with_relations_list(["P26"],"temporal fact","raw/test/")
get_all_item_with_relations_list({"P569":"point"},"time property","raw/test/")

# %%
# import optional relation info
tr_file=open("property_type.tsv")
line=tr_file.readline()
line=tr_file.readline()
optional_relation_dict={}
while line:
    line_info=line.strip().split('\t')
    relation=line_info[0]
    time_type=line_info[1]
    optional_relation_dict[relation]=time_type
    line=tr_file.readline()
print(optional_relation_dict)
tr_file.close()
# Out:
# {'P6': 'period', 'P17': 'period', 'P19': 'point', 'P20': 'point', 'P26': 'period', 'P27': 'period', 'P30': 'period', 'P35': 'period', 'P36': 'period', 'P37': 'period', 'P38': 'period', 'P39': 'period', 'P47': 'period', 'P50': 'period', 'P53': 'period', 'P54': 'period', 'P57': 'period', 'P58': 'period', 'P69': 'period', 'P85': 'period', 'P97': 'period', 'P102': 'period', 'P108': 'period', 'P119': 'period', 'P122': 'period', 'P127': 'period', 'P131': 'period', 'P150': 'period', 'P159': 'period', 'P161': 'period', 'P166': 'point', 'P170': 'point', 'P175': 'point', 'P180': 'period', 'P190': 'period', 'P197': 'period', 'P241': 'period', 'P276': 'period', 'P286': 'period', 'P411': 'point', 'P457': 'point', 'P463': 'period', 'P512': 'point', 'P521': 'period', 'P530': 'period', 'P551': 'point', 'P610': 'period', 'P612': 'period', 'P647': 'point', 'P669': 'period', 'P708': 'period', 'P710': 'point', 'P725': 'period', 'P726': 'period', 'P750': 'period', 'P802': 'period', 'P803': 'period', 'P859': 'period', 'P1038': 'period', 'P1066': 'period', 'P1075': 'period', 'P1344': 'point', 'P1366': 'point', 'P1399': 'point', 'P1411': 'point', 'P1433': 'point', 'P1435': 'period', 'P1448': 'period', 'P1596': 'point', 'P1640': 'period', 'P1652': 'period', 'P1789': 'period', 'P1891': 'point', 'P2238': 'period', 'P2291': 'point', 'P2567': 'point', 'P2568': 'point', 'P2632': 'period', 'P2652': 'period', 'P2828': 'period', 'P2838': 'period', 'P2962': 'period', 'P3085': 'period', 'P3148': 'point', 'P3300': 'period', 'P3342': 'period', 'P3448': 'period', 'P3919': 'period', 'P4002': 'point', 'P5460': 'period', 'P5817': 'period', 'P6087': 'period', 'P6364': 'point'}

# %%
# required relations
common_relation_dict={'P26':'period', 'P108':'period', 'P54':'period', 'P286':'period'}
timeobj_relation_dict={'P569':'point', 'P570':'point'}

# %%
# phase 1 for temporal relations in required relations (all period)
stat_info=get_all_item_with_relations_list(common_relation_dict,"temporal fact","raw/required/common/")
print("Phase 1 done.")

statfilename="PHASE1_RELATION_STAT.txt"
f=open(statfilename,"w")
f.write("?relation\t?count\t?st_count\t?en_count\t?st_en_pairs_count\t?point_count\t?dup_count\n")
for this_r_stat in stat_info:
    f.write("%s\t%d\t%d\t%d\t%d\t%d\t%d\n" %(this_r_stat["r"],this_r_stat["cnt"],this_r_stat["st_cnt"],this_r_stat["en_cnt"],this_r_stat["st_en_pair_ent"],this_r_stat["point_cnt"],this_r_stat["dup_cnt"]))
f.close()
# Out:
# P26 Query complete! count:33857
# P108 Query complete! count:201115
# P54 Query complete! count:920902
# P286 Query complete! count:2930
# Phase 1 done.

# %%
# phase 2 for time property in required relations
stat_info=get_all_item_with_relations_list(timeobj_relation_dict,"time property","raw/required/time_prop")
print("Phase 2 done.")

statfilename="PHASE2_RELATION_STAT.txt"
f=open(statfilename,"w")
f.write("?relation\t?count\t?st_count\t?en_count\t?st_en_pairs_count\t?point_count\t?dup_count\n")
for this_r_stat in stat_info:
    f.write("%s\t%d\t%d\t%d\t%d\t%d\t%d\n" %(this_r_stat["r"],this_r_stat["cnt"],this_r_stat["st_cnt"],this_r_stat["en_cnt"],this_r_stat["st_en_pair_ent"],this_r_stat["point_cnt"],this_r_stat["dup_cnt"]))
f.close()
# Out:
# P569 Query complete! count:3483802
# P570 Query complete! count:1726827
# Phase 2 done.

# %%
# phase 3 for all optional relations 
stat_info=get_all_item_with_relations_list(optional_relation_dict,"temporal fact","raw/optional/common")
print("Phase 3 done.")

statfilename="PHASE3_RELATION_STAT.txt"
f=open(statfilename,"w")
f.write("?relation\t?count\t?st_count\t?en_count\t?st_en_pairs_count\t?point_count\n")
for this_r_stat in stat_info:
    f.write("%s\t%d\t%d\t%d\t%d\t%d\n" %(this_r_stat["r"],this_r_stat["cnt"],this_r_stat["st_cnt"],this_r_stat["en_cnt"],this_r_stat["st_en_pair_ent"],this_r_stat["point_cnt"]))
f.close()
# Out:
# P6 Query complete! count:11571
# P17 Query complete! count:12367
# P19 Query complete! count:12
# P20 Query complete! count:7
# P26 Query complete! count:33857
# P27 Query complete! count:30873
# P30 Query complete! count:6
# P35 Query complete! count:813
# P36 Query complete! count:990
# P37 Query complete! count:69
# P38 Query complete! count:273
# P39 Query complete! count:222472
# P47 Query complete! count:1051
# P50 Query complete! count:59
# P53 Query complete! count:17
# P54 Query complete! count:920902
# P57 Query complete! count:90
# P58 Query complete! count:52
# P69 Query complete! count:51271
# P85 Query complete! count:46
# P97 Query complete! count:2217
# P102 Query complete! count:12803
# P108 Query complete! count:201115
# P119 Query complete! count:4092
# P122 Query complete! count:76
# P127 Query complete! count:32333
# P131 Query complete! count:70146
# P150 Query complete! count:11059
# P159 Query complete! count:1839
# P161 Query complete! count:407
# P166 Query complete! count:196132
# P170 Query complete! count:77
# P175 Query complete! count:351
# P180 Query complete! count:80
# ALL TIME NULL Alert!('http://www.wikidata.org/entity/statement/Q752569-5554010c-42e7-debe-6138-80513eb95f63', 'http://www.wikidata.org/entity/Q752569', 'http://www.wikidata.org/entity/Q331357', None, None, None)
# P190 Query complete! count:6401
# ALL TIME NULL Alert!('http://www.wikidata.org/entity/statement/Q914-C63A6B80-8552-48BA-B933-6E2CEF79ABEE', 'http://www.wikidata.org/entity/Q914', 'http://www.wikidata.org/entity/Q1899', None, None, None)
# P197 Query complete! count:1173
# P241 Query complete! count:2077
# P276 Query complete! count:4870
# P286 Query complete! count:2930
# P411 Query complete! count:479
# P457 Query complete! count:29
# P463 Query complete! count:27504
# P512 Query complete! count:10378
# P521 Query complete! count:10
# P530 Query complete! count:509
# P551 Query complete! count:21146
# ALL TIME NULL Alert!('http://www.wikidata.org/entity/statement/Q5398352-416bb507-49ae-1edd-27ed-e4686e892098', 'http://www.wikidata.org/entity/Q5398352', 'http://www.wikidata.org/entity/Q84', None, None, None)
# P610 Query complete! count:6
# P612 Query complete! count:90
# P647 Query complete! count:155
# P669 Query complete! count:157
# P708 Query complete! count:286
# P710 Query complete! count:2590
# P725 Query complete! count:18
# P726 Query complete! count:60
# P750 Query complete! count:41
# P802 Query complete! count:69
# P803 Query complete! count:279
# P859 Query complete! count:187
# P1038 Query complete! count:59
# P1066 Query complete! count:231
# P1075 Query complete! count:876
# P1344 Query complete! count:2255
# P1366 Query complete! count:1269
# P1399 Query complete! count:833
# P1411 Query complete! count:34573
# P1433 Query complete! count:308
# P1435 Query complete! count:366834
# P1448 Query complete! count:24579
# P1596 Query complete! count:113
# P1640 Query complete! count:50
# P1652 Query complete! count:58
# P1789 Query complete! count:10
# P1891 Query complete! count:989
# P2238 Query complete! count:8
# P2291 Query complete! count:438
# P2567 Query complete! count:12
# P2568 Query complete! count:5110
# P2632 Query complete! count:543
# P2652 Query complete! count:8
# P2828 Query complete! count:7
# P2838 Query complete! count:46
# P2962 Query complete! count:14898
# P3085 Query complete! count:8
# P3148 Query complete! count:4
# P3300 Query complete! count:67
# P3342 Query complete! count:61
# P3448 Query complete! count:4
# P3919 Query complete! count:51
# P4002 Query complete! count:6751
# P5460 Query complete! count:5
# P5817 Query complete! count:1
# P6087 Query complete! count:118
# P6364 Query complete! count:72
# Phase 3 done.

# %%
# merge files into dataset
import os
def convert_time2value(raw_time_str):
    if raw_time_str=="null":
        return raw_time_str
    bc=""
    if raw_time_str.startswith("-"):
        bc="-"
    res=raw_time_str.replace("-","").strip("T")
    if res.endswith("Z"):
        print("time format error:"+bc+res)
    return bc+res
    
dir_list=["raw/optional/common/","raw/required/time_prop/","raw/redundant/"]
r_list=[]
dataset_name="all_relations_with_redundant_wikidata"
dataset_version="alpha-1.3"
merged_f=open(dataset_name+"_"+dataset_version+".tsv","w")
for each_dir in dir_list:
    all_obj=os.listdir(each_dir)
    for each_obj in all_obj:
        dup_cnt=0
        if each_obj.endswith("res.tsv"):
            read_f=open(each_dir+each_obj,"r")
            file_content=read_f.readlines()
            duplicate_chk_set=set()
            for eachline in file_content:
                line_info=eachline.strip().split("\t")
                if eachline in duplicate_chk_set:
                    dup_cnt+=1
                    if dup_cnt<=10:
                        print("Duplicate line found:%s" % eachline)
                    continue
                if line_info[3]!="null" and line_info[4]!="null":
                    st_bc=line_info[3].startswith("-")
                    st_t=line_info[3]
                    en_bc=line_info[4].startswith("-")
                    en_t=line_info[4]
                    if ((not (st_bc and en_bc)) and st_t>en_t) or (st_bc and en_bc and st_t<en_t):
                        print("Time inversion found:%s" %eachline)
                duplicate_chk_set.add(eachline)
                merged_f.write("%s\t%s\t%s\t%s\t%s\n" %(line_info[0],line_info[1],line_info[2],convert_time2value(line_info[3]),convert_time2value(line_info[4])))
            read_f.close()
            print(each_dir+each_obj)
            print(len(duplicate_chk_set))
merged_f.close()
# Out:
# Time inversion found:Q103572	P17	Q723118	18050101	18020101
#
# Time inversion found:Q103572	P17	Q223936	18150101	18050101
#
# Time inversion found:Q1143949	P17	Q34266	18220721	17961031
#
# Time inversion found:Q1540322	P17	Q15180	19221230	19200302
#
# Time inversion found:Q156593	P17	Q36	19181111	19180916
#
# Time inversion found:Q2621007	P17	Q49683	13000101	12600101
#
# Time inversion found:Q262472	P17	Q655621	17110430	15700101
#
# Time inversion found:Q316841	P17	Q459780	18780713	18780712
#
# Time inversion found:Q4051948	P17	Q7318	19420620	19420113
#
# Time inversion found:Q405351	P17	Q219	18780712	18780303
#
# Time inversion found:Q40811	P17	Q15180	19921229	19911226
#
# Time inversion found:Q4150091	P17	Q15180	19320101	19310101
#
# Time inversion found:Q423946	P17	Q36	19891229	19891228
#
# Time inversion found:Q490058	P17	Q142	19010209	18140101
#
# Time inversion found:Q727	P17	Q596214	19450508	19400519
#
# raw/optional/common/P17res.tsv
# 12235
# raw/optional/common/P2568res.tsv
# 5110
# raw/optional/common/P725res.tsv
# 18
# Time inversion found:Q122362	P108	Q50662	19580701	19560101
#
# Time inversion found:Q13422007	P108	Q1675535	20171201	20101101
#
# Time inversion found:Q16477	P108	Q51985	19980101	19930101
#
# Time inversion found:Q180923	P108	Q193755	19790101	19000101
#
# Time inversion found:Q18526707	P108	Q7988660	18960101	18290101
#
# Time inversion found:Q18527016	P108	Q1418223	17820107	17820101
#
# Time inversion found:Q18932363	P108	Q3565810	19420101	19400101
#
# Time inversion found:Q1917975	P108	Q1137665	19180201	19180101
#
# Duplicate line found:Q1957483	P108	Q633529	19960101	20070101
#
# Time inversion found:Q20109628	P108	Q126399	19410101	19400101
#
# Time inversion found:Q21075765	P108	Q1768072	19070508	18110101
#
# Duplicate line found:Q21611923	P108	Q1137665	20050101	20110101
#
# Time inversion found:Q2365271	P108	Q52048361	19551028	19500101
#
# Time inversion found:Q27518465	P108	Q2216535	19910101	19900101
#
# Time inversion found:Q28038527	P108	Q175529	19630101	19600101
#
# Time inversion found:Q3082737	P108	Q4864956	19150101	19100101
#
# Time inversion found:Q30942	P108	Q1054410	19910101	19820101
#
# Time inversion found:Q3119895	P108	Q247577	20150411	20150101
#
# Time inversion found:Q3142266	P108	Q2216535	19250622	19200101
#
# Time inversion found:Q34253	P108	Q28695	19920101	19900101
#
# Duplicate line found:Q37392568	P108	Q1126189	20110101	null
#
# Time inversion found:Q4115189	P108	Q221645	20100101	20010101
#
# Time inversion found:Q41602180	P108	Q189022	20170101	20130430
#
# Time inversion found:Q41820264	P108	Q270272	20170101	20150101
#
# Time inversion found:Q42879076	P108	Q736464	19840101	19800101
#
# Time inversion found:Q42946322	P108	Q1111640	20130101	20060101
#
# Time inversion found:Q443540	P108	Q2216535	19810101	19800101
#
# Time inversion found:Q47487726	P108	Q2992066	19950101	19900101
#
# Duplicate line found:Q50377215	P108	Q861548	20050101	20170101
#
# Time inversion found:Q51088855	P108	Q185246	20170901	20150515
#
# Time inversion found:Q525961	P108	Q2777608	19310101	19300101
#
# Time inversion found:Q54285452	P108	Q2756518	20170928	20130101
#
# Time inversion found:Q54402124	P108	Q1665990	20160801	20160701
#
# Time inversion found:Q55217926	P108	Q2973248	20110321	20110101
#
# Time inversion found:Q55400	P108	Q1136386	19710101	19700101
#
# Time inversion found:Q56760273	P108	Q1353248	19980101	19880101
#
# Time inversion found:Q56810902	P108	Q1804771	19921107	19920101
#
# Time inversion found:Q57042239	P108	Q598841	20180101	20170101
#
# Time inversion found:Q57648777	P108	Q648034	19940101	19900101
#
# Time inversion found:Q597106	P108	Q186941	19410401	19400101
#
# Time inversion found:Q597613	P108	Q977134	19770101	09780101
#
# Time inversion found:Q6001165	P108	Q60045	19370315	19370101
#
# Time inversion found:Q693256	P108	Q1427842	19230101	19200101
#
# Time inversion found:Q90031	P108	Q441101	19650201	19650101
#
# Time inversion found:Q91984	P108	Q517841	19660101	16680101
#
# raw/optional/common/P108res.tsv
# 135150
# Time inversion found:Q12328940	P463	Q12336901	20010801	20010101
#
# Time inversion found:Q1382032	P463	Q939743	20070625	20061001
#
# Duplicate line found:Q16980860	P463	Q666410	19810101	null
#
# Duplicate line found:Q3048878	P463	Q666410	19870101	null
#
# Duplicate line found:Q3377548	P463	Q11878265	19980101	null
#
# Duplicate line found:Q5806522	P463	Q335746	19770101	19890101
#
# Time inversion found:Q5930255	P463	Q1185863	19820101	18960101
#
# Time inversion found:Q60749919	P463	Q150793	19380501	19380101
#
# raw/optional/common/P463res.tsv
# 27321
# raw/optional/common/P521res.tsv
# 10
# Time inversion found:Q22008228	P2291	Q20962071	20151229	20151201
#
# raw/optional/common/P2291res.tsv
# 436
# Duplicate line found:Q14709240	P1435	Q19558910	19760101	null
#
# Duplicate line found:Q16406376	P1435	Q12358501	19970520	null
#
# Duplicate line found:Q19945459	P1435	Q10387575	19891122	20150511
#
# Duplicate line found:Q22938803	P1435	Q10387575	19280620	null
#
# Duplicate line found:Q22965616	P1435	Q10387575	19950403	20170410
#
# Time inversion found:Q27048444	P1435	Q385405	20170407	20151021
#
# Time inversion found:Q28758154	P1435	Q385405	19641222	19640101
#
# Duplicate line found:Q2901485	P1435	Q35863415	19761230	null
#
# Duplicate line found:Q29573153	P1435	Q12053139	19761014	null
#
# Duplicate line found:Q425898	P1435	Q23712	19310603	null
#
# Duplicate line found:Q42841215	P1435	Q12637954	20030605	null
#
# Duplicate line found:Q42841225	P1435	Q12637954	20030121	null
#
# raw/optional/common/P1435res.tsv
# 366700
# Duplicate line found:Q109860	P97	Q22923081	06290101	06390101
#
# Time inversion found:Q269931	P97	Q51088606	12890101	12880101
#
# Duplicate line found:Q316888	P97	Q22923081	06130101	06130101
#
# Time inversion found:Q54227042	P97	Q28003317	-180000101	-80000201
#
# Time inversion found:Q7531891	P97	Q19643	15480101	00010101
#
# Time inversion found:Q935839	P97	Q52145465	11960101	11060101
#
# raw/optional/common/P97res.tsv
# 2172
# raw/optional/common/P3300res.tsv
# 65
# Time inversion found:Q1085	P6	Q31314889	18480515	18480501
#
# Time inversion found:Q2069665	P6	Q180322	30190101	01200101
#
# Time inversion found:Q42307965	P6	Q3741429	20170101	20140101
#
# Time inversion found:Q48089	P6	Q1477239	19570101	01950101
#
# Duplicate line found:Q801	P6	Q184351	19861020	19920713
#
# raw/optional/common/P6res.tsv
# 11408
# Duplicate line found:Q14198040	P710	Q1189	20130811	20130811
#
# Duplicate line found:Q14199292	P710	Q1189	20130816	20130816
#
# Duplicate line found:Q1805466	P710	Q1189	20070828	20070828
#
# Duplicate line found:Q20312702	P710	Q1189	20150502	20150502
#
# Duplicate line found:Q20785653	P710	Q1189	20150823	20150823
#
# Duplicate line found:Q20805767	P710	Q1189	20020719	20020719
#
# Duplicate line found:Q2107966	P710	Q1189	20110902	20110902
#
# Duplicate line found:Q2313355	P710	Q1189	20090815	20090815
#
# Duplicate line found:Q2313355	P710	Q1189	20090816	20090816
#
# Duplicate line found:Q2334948	P710	Q1189	20110828	20110828
#
# Time inversion found:Q28913510	P710	Q3010166	20140215	20130128
#
# raw/optional/common/P710res.tsv
# 2540
# Duplicate line found:Q1003422	P54	Q824850	20160101	null
#
# Time inversion found:Q1024135	P54	Q1422	19700101	01970101
#
# Duplicate line found:Q1028024	P54	Q704	20110101	20150101
#
# Time inversion found:Q10284618	P54	Q270995	20080529	20080101
#
# Time inversion found:Q10331542	P54	Q2721746	20130101	20000101
#
# Duplicate line found:Q1033719	P54	Q18232	20140101	20150101
#
# Duplicate line found:Q10436504	P54	Q201969	20170101	20170101
#
# Duplicate line found:Q10552708	P54	Q104770	20120101	20150101
#
# Duplicate line found:Q10555349	P54	Q15214308	20140101	20140101
#
# Duplicate line found:Q10556846	P54	Q193377	20120101	20150101
#
# Time inversion found:Q10556901	P54	Q909189	19730101	19640101
#
# Time inversion found:Q10557476	P54	Q669130	20150601	20150101
#
# Time inversion found:Q1077389	P54	Q219602	20140416	20140101
#
# Duplicate line found:Q1079931	P54	Q1520422	19960101	19970101
#
# Duplicate line found:Q1082991	P54	Q80964	20100101	20110101
#
# Time inversion found:Q10974101	P54	Q15978479	19990101	19000101
#
# Time inversion found:Q10974863	P54	Q5298843	20110101	20000101
#
# Time inversion found:Q11035210	P54	Q7504249	19990101	19000101
#
# Time inversion found:Q11128287	P54	Q6785922	20090101	20000101
#
# Time inversion found:Q11146901	P54	Q8023431	20020101	20000101
#
# Duplicate line found:Q1117392	P54	Q2536648	20110101	20110101
#
# Time inversion found:Q11310092	P54	Q11386080	20141001	20130501
#
# Time inversion found:Q11728624	P54	Q463147	19630101	19570101
#
# Time inversion found:Q117743	P54	Q27076773	20160101	20000101
#
# Time inversion found:Q117743	P54	Q15895905	20130101	20000101
#
# Time inversion found:Q117743	P54	Q21820715	20160101	20000101
#
# Time inversion found:Q1187662	P54	Q27657863	20160101	20000101
#
# Time inversion found:Q1187662	P54	Q20648957	20180101	20000101
#
# Time inversion found:Q11970340	P54	Q2675558	20070701	20020630
#
# Time inversion found:Q1262255	P54	Q757109	21060801	20171101
#
# Time inversion found:Q12987694	P54	Q4983260	20120101	20000101
#
# Time inversion found:Q12988113	P54	Q7842476	20050101	20000101
#
# Time inversion found:Q1299667	P54	Q170561	19870101	19850101
#
# raw/optional/common/P1399res.tsv
# 829
# raw/optional/common/P457res.tsv
# 29
# Time inversion found:Q316691	P1066	Q3180515	17330101	17300101
#
# raw/optional/common/P1066res.tsv
# 226
# Duplicate line found:Q102116	P569	1570-12-12 00:00:00Z	15701212	15701212
#
# Duplicate line found:Q10299689	P569	1437-01-01 00:00:00Z	14370101	14370101
#
# Duplicate line found:Q10311400	P569	1553-01-01 00:00:00Z	15530101	15530101
#
# Duplicate line found:Q103299	P569	1940-01-01 00:00:00Z	19400101	19400101
#
# Duplicate line found:Q10356170	P569	1520-01-01 00:00:00Z	15200101	15200101
#
# Duplicate line found:Q10411463	P569	1521-01-01 00:00:00Z	15210101	15210101
#
# Duplicate line found:Q10608167	P569	1580-01-01 00:00:00Z	15800101	15800101
#
# Duplicate line found:Q1071000	P569	1530-01-01 00:00:00Z	15300101	15300101
#
# Duplicate line found:Q1090727	P569	1902-01-17 00:00:00Z	19020117	19020117
#
# Duplicate line found:Q1091388	P569	1574-10-25 00:00:00Z	15741025	15741025
#
# raw/required/time_prop/P569res.tsv
# 3474025
# Duplicate line found:Q102062	P570	1994-01-01 00:00:00Z	19940101	19940101
#
# Duplicate line found:Q10305051	P570	1886-01-01 00:00:00Z	18860101	18860101
#
# Duplicate line found:Q103254	P570	1958-01-01 00:00:00Z	19580101	19580101
#
# Duplicate line found:Q10411463	P570	1560-01-01 00:00:00Z	15600101	15600101
#
# Duplicate line found:Q10537991	P570	1289-01-01 00:00:00Z	12890101	12890101
#
# Duplicate line found:Q106837	P570	1206-01-01 00:00:00Z	12060101	12060101
#
# Duplicate line found:Q11487537	P570	1528-01-01 00:00:00Z	15280101	15280101
#
# Duplicate line found:Q11717876	P570	1560-01-01 00:00:00Z	15600101	15600101
#
# Duplicate line found:Q11748993	P570	1503-01-01 00:00:00Z	15030101	15030101
#
# Duplicate line found:Q11765402	P570	1419-01-01 00:00:00Z	14190101	14190101
#
# raw/required/time_prop/P570res.tsv
# 1714690
# raw/redundant/P1611res.tsv
# 211
# Duplicate line found:Q6761084	P1635	Maria Cattarina	null	null
#
# raw/redundant/P1635res.tsv
# 358
# raw/redundant/P3533res.tsv
# 942
# raw/redundant/P1971res.tsv
# 13344
# raw/redundant/P1290res.tsv
# 142
# raw/redundant/P742res.tsv
# 20253
# raw/redundant/P109res.tsv
# 13611
# raw/redundant/P4193res.tsv
# 243
# raw/redundant/P1340res.tsv
# 4886
# raw/redundant/P3539res.tsv
# 16146
# raw/redundant/P811res.tsv
# 53
# raw/redundant/P941res.tsv
# 2410
# raw/redundant/P2359res.tsv
# 3244
# raw/redundant/P641res.tsv
# 1090406
# raw/redundant/P2035res.tsv
# 5773
# raw/redundant/P800res.tsv
# 47248
# raw/redundant/P2650res.tsv
# 2708
# raw/redundant/P3536res.tsv
# 1218
# raw/redundant/P1884res.tsv
# 5376
# raw/redundant/P2013res.tsv
# 80570
# raw/redundant/P410res.tsv
# 87315
# raw/redundant/P4612res.tsv
# 152
# raw/redundant/P3205res.tsv
# 31
# raw/redundant/P1642res.tsv
# 1
# raw/redundant/P550res.tsv
# 46
# raw/redundant/P3527res.tsv
# 4698
# raw/redundant/P185res.tsv
# 16703
# raw/redundant/P3373res.tsv
# 240574
# raw/redundant/P4353res.tsv
# 173
# raw/redundant/P3502res.tsv
# 12090
# raw/redundant/P841res.tsv
# 3954
# Duplicate line found:Q16397	P1559	李振藩	null	null
#
# Duplicate line found:Q312477	P1559	Кубрат	null	null
#
# Duplicate line found:Q197209	P1559	張潔雯	null	null
#
# Duplicate line found:Q14279	P1559	Giovanni Domenico Cassini	null	null
#
# Duplicate line found:Q240274	P1559	Christian Herter	null	null
#
# Duplicate line found:Q2601551	P1559	庾耀东	null	null
#
# Duplicate line found:Q134720	P1559	Martina Hingisová	null	null
#
# Duplicate line found:Q113734	P1559	Evelyne Neff	null	null
#
# Duplicate line found:Q1931146	P1559	陳潔英	null	null
#
# Duplicate line found:Q524467	P1559	伏明天	null	null
#
# raw/redundant/P1559res.tsv
# 331888
# raw/redundant/P450res.tsv
# 1696
# raw/redundant/P1593res.tsv
# 61
# raw/redundant/P3538res.tsv
# 8258
# raw/redundant/P1836res.tsv
# 1
# raw/redundant/P1950res.tsv
# 12978
# raw/redundant/P22res.tsv
# 145688
# raw/redundant/P3532res.tsv
# 3515
# raw/redundant/P2358res.tsv
# 4179
# raw/redundant/P91res.tsv
# 1565
# raw/redundant/P2389res.tsv
# 5761
# raw/redundant/P172res.tsv
# 64468
# raw/redundant/P3526res.tsv
# 96
# raw/redundant/P1350res.tsv
# 2118
# raw/redundant/P3602res.tsv
# 29338
# raw/redundant/P5054res.tsv
# 2
# raw/redundant/P2462res.tsv
# 181
# raw/redundant/P1308res.tsv
# 3633
# raw/redundant/P1875res.tsv
# 3040
# raw/redundant/P1000res.tsv
# 157
# raw/redundant/P1035res.tsv
# 339
# raw/redundant/P1416res.tsv
# 17639
# raw/redundant/P451res.tsv
# 7906
# raw/redundant/P1731res.tsv
# 320
# raw/redundant/Q59093540res.tsv
# 0
# raw/redundant/P4292res.tsv
# 13
# raw/redundant/P1782res.tsv
# 923
# raw/redundant/P3833res.tsv
# 137
# raw/redundant/P184res.tsv
# 19231
# raw/redundant/P1775res.tsv
# 10
# raw/redundant/P2365res.tsv
# 133
# raw/redundant/Q60469790res.tsv
# 0
# raw/redundant/P990res.tsv
# 868
# raw/redundant/P1196res.tsv
# 70502
# raw/redundant/P1318res.tsv
# 69
# raw/redundant/P735res.tsv
# 3002473
# raw/redundant/P1026res.tsv
# 6127
# raw/redundant/P3845res.tsv
# 341
# raw/redundant/P3438res.tsv
# 787
# raw/redundant/P2021res.tsv
# 2246
# raw/redundant/P1543res.tsv
# 214
# raw/redundant/P3899res.tsv
# 169
# Duplicate line found:Q5512324	P1477	George Eduard Albert Krugers	null	null
#
# Duplicate line found:Q47561	P1477	Ivo Andrić	null	null
#
# Duplicate line found:Q882	P1477	Charles Spencer Chaplin	null	null
#
# Duplicate line found:Q5121104	P1477	Cinta Laura Kiehl	null	null
#
# Duplicate line found:Q10706370	P1477	Javid Iqbal Aslam	null	null
#
# Duplicate line found:Q10706370	P1477	Javid Iqbal Aslam	null	null
#
# Duplicate line found:Q233977	P1477	Lene Marlin Pedersen	null	null
#
# Duplicate line found:Q1083878	P1477	Ida Emilia Aalberg	null	null
#
# Duplicate line found:Q17384404	P1477	Solveig Johanna Irja von Uexküll-Gyllenband	null	null
#
# Duplicate line found:Q2938941	P1477	Carl Johan von Heideken	null	null
#
# raw/redundant/P1477res.tsv
# 67501
# raw/redundant/P1050res.tsv
# 7672
# raw/redundant/P607res.tsv
# 165843
# raw/redundant/P103res.tsv
# 79959
# raw/redundant/P3789res.tsv
# 173
# raw/redundant/P1787res.tsv
# 980
# raw/redundant/P66res.tsv
# 719
# raw/redundant/P1412res.tsv
# 693745
# raw/redundant/P140res.tsv
# 168977
# raw/redundant/P1455res.tsv
# 777
# raw/redundant/P531res.tsv
# 16
# raw/redundant/P101res.tsv
# 108413
# raw/redundant/P1345res.tsv
# 91
# raw/redundant/P1303res.tsv
# 83448
# raw/redundant/P734res.tsv
# 1285091
# raw/redundant/P1785res.tsv
# 60
# raw/redundant/P2416res.tsv
# 23352
# raw/redundant/P412res.tsv
# 25078
# raw/redundant/P2893res.tsv
# 42
# raw/redundant/P2003res.tsv
# 33257
# raw/redundant/P812res.tsv
# 446
# raw/redundant/P768res.tsv
# 3282
# raw/redundant/P3716res.tsv
# 3334
# raw/redundant/P1643res.tsv
# 0
# raw/redundant/P1786res.tsv
# 377
# raw/redundant/P135res.tsv
# 45534
# raw/redundant/P263res.tsv
# 1292
# raw/redundant/P40res.tsv
# 190868
# raw/redundant/P598res.tsv
# 6853
# raw/redundant/P3368res.tsv
# 311
# raw/redundant/P737res.tsv
# 8968
# raw/redundant/P106res.tsv
# 4876313
# raw/redundant/P1321res.tsv
# 1896
# raw/redundant/P2298res.tsv
# 252
# raw/redundant/P1853res.tsv
# 28368
# raw/redundant/P1780res.tsv
# 9
# Duplicate line found:Q302	P2561	Cristo	null	null
#
# Duplicate line found:Q3701796	P2561	Daniela Georgieva	null	null
#
# Duplicate line found:Q612	P2561	Dubai	null	null
#
# Duplicate line found:Q43016	P2561	тысяча	null	null
#
# Duplicate line found:Q2586176	P2561	Loyola	null	null
#
# Duplicate line found:Q2586176	P2561	Loyola	null	null
#
# Duplicate line found:Q2655347	P2561	Urola Kosta	null	null
#
# Duplicate line found:Q2655347	P2561	Urola Kosta	null	null
#
# Duplicate line found:Q2655347	P2561	Урола-Коста	null	null
#
# Duplicate line found:Q6637462	P2561	Sharona Aron	null	null
#
# raw/redundant/P2561res.tsv
# 8642
# raw/redundant/P2873res.tsv
# 545
# raw/redundant/P1283res.tsv
# 477
# raw/redundant/P511res.tsv
# 2261
# raw/redundant/P470res.tsv
# 900
# raw/redundant/P3505res.tsv
# 36
# raw/redundant/P1598res.tsv
# 7584
# raw/redundant/P937res.tsv
# 240179
# raw/redundant/P4175res.tsv
# 119
# raw/redundant/P136res.tsv
# 835037
# raw/redundant/P25res.tsv
# 44953
# raw/redundant/P1429res.tsv
# 140
# raw/redundant/P1049res.tsv
# 1232
# raw/redundant/P358res.tsv
# 5009
# raw/redundant/P468res.tsv
# 266
# raw/redundant/P1393res.tsv
# 24
# raw/redundant/P2218res.tsv
# 253
# raw/redundant/P856res.tsv
# 976545
# raw/redundant/P6275res.tsv
# 3394
# raw/redundant/P21res.tsv
# 4048350
# raw/redundant/P2831res.tsv
# 8
# raw/redundant/P2097res.tsv
# 291
# raw/redundant/P3909res.tsv
# 71
# raw/redundant/P413res.tsv
# 307927
# raw/redundant/P1677res.tsv
# 1
# raw/redundant/P1327res.tsv
# 6058
# raw/redundant/P3091res.tsv
# 410
# raw/redundant/P2770res.tsv
# 345
# raw/redundant/P2366res.tsv
# 4
# raw/redundant/P3902res.tsv
# 17
# Duplicate line found:Q177928	P1449	El Sid	null	null
#
# Duplicate line found:Q18115751	P1449	Nando	null	null
#
# Duplicate line found:Q18115751	P1449	Nando	null	null
#
# Duplicate line found:Q44881	P1449	Dolk	null	null
#
# Duplicate line found:Q26807	P1449	PG	null	null
#
# Duplicate line found:Q274711	P1449	Minken	null	null
#
# Duplicate line found:Q463545	P1449	Air France	null	null
#
# Duplicate line found:Q48355624	P1449	Синоптик	null	null
#
# Duplicate line found:Q55765768	P1449	Effi	null	null
#
# Duplicate line found:Q510754	P1449	Frøhans	null	null
#
# raw/redundant/P1449res.tsv
# 9719
# raw/redundant/P553res.tsv
# 1070
# raw/redundant/P552res.tsv
# 1312

# %%
#test temporal fact query sparql
relation="P1789"
query = '''
    SPARQL
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    SELECT DISTINCT ?e1 ?e2 ?st ?en
    WHERE
    {{
        # ?e1 p:{} ?s.
        # ?s ps:{} ?e2.

        {{?s pq:P580 ?st.
        OPTIONAL {{?s pq:P582 ?en.}}}}
        UNION
        {{?s pq:P582 ?en.
        OPTIONAL {{?s pq:P580 ?st.}}}}
    }}
    '''.format(relation,relation)
# print(query)
results=query_with_odbc(query)

print(results)
query_res=[]
print("%s Query complete!" % relation)
for each_result in results:
    temporal_fact={}
    temporal_fact["s"]=each_result["e1"]["value"][31:]
    temporal_fact["p"]=relation
    temporal_fact["o"]=each_result["e2"]["value"][31:]
    
    if "st" in each_result:
        if each_result["st"]["type"]=="typed-literal":
            if each_result["st"]["datatype"]!="http://www.w3.org/2001/XMLSchema#dateTime":
                print("DatatypeAlert!type:%s",each_result["en"]["datatype"])
            temporal_fact["t1"]=each_result["st"]["value"].split("T")[0]
        else:
            continue
    else:
        temporal_fact["t1"]="null"
    if "en" in each_result:
        if each_result["en"]["type"]=="typed-literal":
            if each_result["en"]["datatype"]!="http://www.w3.org/2001/XMLSchema#dateTime":
                print("DatatypeAlert!type:%s",each_result["en"]["datatype"])
            temporal_fact["t2"]=each_result["en"]["value"].split("T")[0]
        else:
            continue
    else:
        temporal_fact["t2"]="null"
    query_res.append(temporal_fact)

# f=open("%sres.csv" %relation,"w")
# for tf in query_res:
#     f.write("%s,%s,%s,%s,%s\n" %(tf["s"],tf["p"],tf["o"],tf["t1"],tf["t2"]))
# f.close()
# print(query_res)

# %%
#test time property query sparql
relation="P569"
query = '''
        SPARQL
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        SELECT  ?e1 \"{}\" ?time
        WHERE
        {{
            # ?e1 wdt:{} ?time.
        }}
    '''.format(relation,relation)
# print(query)
results=query_with_odbc(query)
print(results)
query_res=[]
print("%s Query complete!" % relation)
for each_result in results:
    if "literal" in each_result["time"]["type"]:
        temporal_fact={}
        temporal_fact["s"]=each_result["e1"]["value"][31:]
        temporal_fact["p"]=each_result["callret-1"]["value"]
        temporal_fact["o"]=each_result["time"]["value"]
        temporal_fact["t1"]=each_result["time"]["value"]
        temporal_fact["t2"]=each_result["time"]["value"]
        query_res.append(temporal_fact)
# f=open("%sres.csv" %relation,"w")
# for tf in query_res:
#     f.write("%s,%s,%s,%s,%s\n" %(tf["s"],tf["p"],tf["o"],tf["t1"],tf["t2"]))
# f.close()
# print(query_res)

# %%
# multi-value stat
relation_list=optional_relation_dict.keys()#["P26","P54","P108","P286","P166"]
property_list=["P580","P582","P585"]
relation=relation_list[0]
time_property=property_list[0]
for relation in relation_list:
    print(relation,end="")
    for time_property in property_list:
        query = '''
                SPARQL
                PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                SELECT ?e1 ?e2 ?s COUNT(?e2)
                WHERE
                {{
                    # ?e1 p:{} ?s.
                    # ?s ps:{} ?e2.
                    # ?s a <http://wikiba.se/ontology#Statement>.
                    # ?s pq:{} ?timevalue.
                }}
                GROUP BY ?e1 ?e2 ?s 
                HAVING (COUNT(?e2)>1)
            '''.format(relation,relation,time_property)
        # print(query)
        results=query_with_odbc(query)
        
        # print(results[0])
        s_cnt=len(results)
        cnt=0
        for each_data in results:
            cnt=cnt+int(each_data['callret-3']['value'])
        print("\t%d(%d statements)" %(cnt,s_cnt),end="")
    print("")

# %%
# prefix limit check
relation_list=optional_relation_dict.keys()
for relation in relation_list:
    query = '''
            SPARQL
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            SELECT COUNT DISTINCT ?e1
            WHERE
            {{
                # ?e1 a <http://wikiba.se/ontology#Item>.
                # ?s a <http://wikiba.se/ontology#Statement>.
                # ?e1 p:{} ?s.
            }}
        '''.format(relation)
    # print(query)
    prefix_limit_results=query_with_odbc(query)
    # prefix_limit_e1=set([str(i['e1']) for i in prefix_limit_results])
    prefix_limit_cnt = int(prefix_limit_results[0]['callret-0']['value'])
    # print(prefix_limit_cnt)

    query = '''
            SPARQL
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            SELECT COUNT DISTINCT ?e1
            WHERE
            {{
                # ?e1 a <http://wikiba.se/ontology#Property>.
                # ?s a <http://wikiba.se/ontology#Statement>.
                # ?e1 p:{} ?s.
            }}
        '''.format(relation)
    # print(query)
    p_prefix_limit_results=query_with_odbc(query)
    # prefix_limit_e1=set([str(i['e1']) for i in prefix_limit_results])
    p_prefix_limit_cnt = int(p_prefix_limit_results[0]['callret-0']['value'])

    query = '''
            SPARQL
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            SELECT COUNT DISTINCT ?e1
            WHERE
            {{
                # ?s a <http://wikiba.se/ontology#Statement>.
                # ?e1 p:{} ?s.
            }}
        '''.format(relation)
    # print(query)
    all_results=query_with_odbc(query)
    # all_e1=set([str(i['e1']) for i in all_results])
    all_cnt = int(all_results[0]['callret-0']['value'])
    # print(all_cnt)
    if prefix_limit_cnt==all_cnt:
        print("%s\tEQUAL\t%d" %(relation,all_cnt))
    else:
        print("%s\tINEQUAL\t%d\t%d\t%d\t%s" %(relation,prefix_limit_cnt,p_prefix_limit_cnt,all_cnt,prefix_limit_cnt+p_prefix_limit_cnt==all_cnt))
        # print(all_e1-prefix_limit_e1)

# %%
# check cnt>=100w
relation_list=optional_relation_dict.keys()
for relation in relation_list:
    query = '''
        SPARQL
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        SELECT COUNT DISTINCT ?e1 ?e2 ?st ?en ?time ?s
        WHERE
        {{
            # ?e1 p:{} ?s.
            # ?s ps:{} ?e2.
            # ?s a <http://wikiba.se/ontology#Statement>.
            # ?e1 a <http://wikiba.se/ontology#Item>.

            {{
                # ?s pq:P580 ?st.
                OPTIONAL {{?s pq:P582 ?en.}}
                OPTIONAL {{?s pq:P585 ?time.}}
            }}
            UNION
            {{
                # ?s pq:P582 ?en.
                OPTIONAL {{?s pq:P580 ?st.}}
                OPTIONAL {{?s pq:P585 ?time.}}
            }}
            UNION
            {{
                # ?s pq:P585 ?time.
                OPTIONAL {{?s pq:P580 ?st.}}
                OPTIONAL {{?s pq:P582 ?en.}}
            }}
        }}
        '''.format(relation,relation)
    # print(query)
    results==query_with_odbc(query)
    print("%s\t%s"%(relation,results[0]['callret-0']['value']))

# %%
# check cnt>=100w
relation_list=["P569","P570"]
for relation in relation_list:
    query = '''
        SPARQL
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        SELECT COUNT DISTINCT ?e1 ?e2 ?st ?en ?s
        WHERE
        {{
            # ?e1 p:{} ?s.
            # ?s ps:{} ?e2.

            OPTIONAL {{?s pq:P580 ?st.}}
            OPTIONAL {{?s pq:P582 ?en.}}
        }}
        '''.format(relation,relation)
    # print(query)
    results==query_with_odbc(query)
    print("%s\t%s"%(relation,results[0]['callret-0']['value']))

# %% [markdown]
# SELECT ?typ ?typLabel
# WHERE
# {
#   wd:P1435 (wdt:P1647|wdt:P279|wdt:P31)* ?typ.
#   ?typ wdt:P31 wd:Q107649491.
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
# }

# %%
p_type={"Q22964231":"Wikidata property for human relationships","Q18608871":"Wikidata property for items about people","Q57955292":"Wikidata property for items about people or organisations"}
for each_p_type in p_type.keys():
    print("P_TYPE:"+p_type[each_p_type])
    query = '''
        SPARQL
        SELECT ?typ ?label
        WHERE
        {{
            # ?typ wdt:P31 wd:{}.
            # ?typ rdfs:label ?label.filter(lang(?label)='en')
        }}
        '''.format(each_p_type)
    results=query_with_odbc(query)
    for each_p in results:
        p_suffix=each_p[0].replace("http://www.wikidata.org/entity/","")
        query='''
        SPARQL
        SELECT COUNT DISTINCT ?e1 ?e2
        WHERE
        {{
            # ?e1 a <http://wikiba.se/ontology#Item>.
            # ?e1 wdt:{} ?e2.
        }}
        '''.format(p_suffix)
        results=query_with_odbc(query)

        print("P:%s(%s) total count:%d" %(each_p[1],p_suffix,int(results[0][0])))

        query='''
        SPARQL
        SELECT DISTINCT ?e1typ ?e1Label ?e2typ ?e2Label COUNT(?e1typ) COUNT(?e2typ)
        WHERE
        {{
        # ?e1 a <http://wikiba.se/ontology#Item>.
        # ?e1 wdt:{} ?e2.
        # ?e1 wdt:P31 ?e1typ.
        # ?e1typ rdfs:label ?e1Label.filter(lang(?e1Label)='en').
        # ?e2 wdt:P31 ?e2typ.
        # ?e2typ rdfs:label ?e2Label.filter(lang(?e2Label)='en').
        }}
        GROUP BY ?e1typ ?e1Label ?e2typ ?e2Label
        ORDER BY DESC(COUNT(?e1typ)) 
        LIMIT 10
        '''.format(p_suffix)
        results=query_with_odbc(query)
        for each_typ_comb in results:
            print(each_typ_comb)
        print("-"*30)
    print("="*30)

# %%
for relation in optional_relation_dict.keys():
    query="""
    SPARQL
    SELECT ?ptyp ?ptyplabel
    WHERE
    {{
        wd:{} wdt:P31 ?ptyp.
        # ?ptyp wdt:P31 wd:Q107649491.
        # ?ptyp rdfs:label ?ptyplabel.filter(lang(?ptyplabel)='en').
    }}
    """.format(relation)
    results=query_with_odbc(query)
    for each_result in results:
        print(each_result)

# %%
p_type={"Q22964231":"Wikidata property for human relationships","Q18608871":"Wikidata property for items about people","Q57955292":"Wikidata property for items about people or organisations"}
file_path="raw/redundant"
for each_p_type in p_type.keys():
    print("P_TYPE:"+p_type[each_p_type])
    query = '''
        SPARQL
        SELECT ?typ ?label
        WHERE
        {{
            # ?typ wdt:P31 wd:{}.
            # ?typ rdfs:label ?label.filter(lang(?label)='en')
        }}
        '''.format(each_p_type)
    results_p_group=query_with_odbc(query)
    # print(results)
    for each_p in results_p_group:
        relation=each_p[0].replace("http://www.wikidata.org/entity/","")
        if relation not in optional_relation_dict.keys() and relation not in timeobj_relation_dict.keys():
            with open("%s/%sres.tsv" %(file_path,relation),"w") as f: 
                query = '''
                    SPARQL
                    PREFIX wd: <http://www.wikidata.org/entity/>
                    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                    SELECT DISTINCT  ?e1 ?e2 
                    WHERE
                    {{
                        # ?e1 wdt:{} ?e2.
                        # ?e1 a <http://wikiba.se/ontology#Item>.
                    }}
                    '''.format(relation)
                results=query_with_odbc(query)
                print("%s query complete!" %relation)
                for each_result in results:
                    f.write("%s\t%s\t%s\tnull\tnull\n" %(each_result[0].replace("http://www.wikidata.org/entity/",""),relation,each_result[1].replace("http://www.wikidata.org/entity/","")))
            f.close()
# Out:
# P_TYPE:Wikidata property for human relationships
# P25 query complete!
# P1290 query complete!
# P22 query complete!
# P40 query complete!
# P3373 query complete!
# P1971 query complete!
# P451 query complete!
# P_TYPE:Wikidata property for items about people
# P140 query complete!
# P136 query complete!
# P358 query complete!
# P569 query complete!
# P570 query complete!
# P856 query complete!
# P4193 query complete!
# P1775 query complete!
# P135 query complete!
# P450 query complete!
# P2298 query complete!
# P1853 query complete!
# P607 query complete!
# P3716 query complete!
# P109 query complete!
# P2831 query complete!
# P937 query complete!
# P1416 query complete!
# P553 query complete!
# P1000 query complete!
# P2021 query complete!
# P470 query complete!
# P1412 query complete!
# P106 query complete!
# P184 query complete!
# P5054 query complete!
# P641 query complete!
# P4292 query complete!
# P1308 query complete!
# P1393 query complete!
# P2097 query complete!
# P21 query complete!
# P2389 query complete!
# P4353 query complete!
# P531 query complete!
# P598 query complete!
# P768 query complete!
# P2770 query complete!
# P811 query complete!
# P263 query complete!
# P552 query complete!
# P1026 query complete!
# P812 query complete!
# P990 query complete!
# P2561 query complete!
# P1449 query complete!
# P2358 query complete!
# P734 query complete!
# P1782 query complete!
# P737 query complete!
# P3502 query complete!
# P468 query complete!
# P742 query complete!
# P735 query complete!
# P1635 query complete!
# P1327 query complete!
# P1787 query complete!
# P2359 query complete!
# P2365 query complete!
# P2366 query complete!
# P1350 query complete!
# P1455 query complete!
# P2462 query complete!
# P1477 query complete!
# P1559 query complete!
# P1950 query complete!
# P2003 query complete!
# P1303 query complete!
# P1731 query complete!
# P3205 query complete!
# P3091 query complete!
# P941 query complete!
# P172 query complete!
# P3438 query complete!
# P6275 query complete!
# P2035 query complete!
# P4612 query complete!
# P3505 query complete!
# P103 query complete!
# P1050 query complete!
# P1196 query complete!
# P800 query complete!
# P1785 query complete!
# P1593 query complete!
# P1677 query complete!
# P550 query complete!
# P1049 query complete!
# P2650 query complete!
# P1598 query complete!
# P410 query complete!
# P2013 query complete!
# P3845 query complete!
# P1786 query complete!
# P1875 query complete!
# P91 query complete!
# P66 query complete!
# P1340 query complete!
# P1884 query complete!
# P1836 query complete!
# P1543 query complete!
# P1429 query complete!
# P2893 query complete!
# P3789 query complete!
# P3899 query complete!
# P1345 query complete!
# P3368 query complete!
# P3538 query complete!
# P3833 query complete!
# P413 query complete!
# P412 query complete!
# P3527 query complete!
# P1283 query complete!
# P841 query complete!
# P1642 query complete!
# P1643 query complete!
# P3526 query complete!
# P3532 query complete!
# P3533 query complete!
# P3536 query complete!
# P3539 query complete!
# P3909 query complete!
# P3602 query complete!
# P185 query complete!
# P1611 query complete!
# P2416 query complete!
# P1321 query complete!
# P1780 query complete!
# P511 query complete!
# P2873 query complete!
# P1035 query complete!
# P3902 query complete!
# P2218 query complete!
# P1318 query complete!
# Q59093540 query complete!
# P4175 query complete!
# Q60469790 query complete!
# P_TYPE:Wikidata property for items about people or organisations
# P101 query complete!

# %%
query="""
                SPARQL
                SELECT COUNT DISTINCT ?s ?e1 ?e2
                WHERE
                {{
                    # ?e1 p:P463 ?s.
                    # ?s ps:P463 ?e2.
                    # ?s a <http://wikiba.se/ontology#Statement>.
                    # ?e1 a <http://wikiba.se/ontology#Item>.

                }}
                """
results=query_with_odbc(query)
print(results)
# Out:
# [(246456, )]
